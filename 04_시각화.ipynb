# %% [markdown]
# ## 4장. 데이터시각화
# - matplolib는 시각화 대상이 numpy array
# - seaborn은 시각화 대상이 pandas DataFrame, Series :
#  - schema 정보를 이용하여 쉽게 시각화 대상을 결정할 수 있다.
#  - ticklabel, label 정보를 추가적으로 입력할 필요가 없다.

# %% [markdown]
# ### 1. 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe") 
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89
# <class 'pandas.core.frame.DataFrame'>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10,5)
# plt.rcParams['lines.linewidth'] = 2
# plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = True

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure()
# axes1 = fig.add_subplot(2,2,1)
axes1 = fig.add_subplot(221)
axes2 = fig.add_subplot(222)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'r*') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'b+') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'k.')

fig

# %% [markdown]
# 각각의 도화지에 대한 제목을 부여할 때

# %%
axes1.set_title("dataset_1") 
axes2.set_title("dataset_2")
axes3.set_title("dataset_3") 
axes4.set_title("dataset_4")

fig

# %% [markdown]
# 캔버스 전체에 대한 제목을 부여할 때

# %%
fig.suptitle("Anscombe Data")

fig

# %%
fig.tight_layout()

fig

# %% [markdown]
# ### [Quiz] 아래와 같은 결과를 생성하라.
# | stats | x1 | y1 | x2 | y2 | x3 | y3 | x4 | y4 |
# |---|---:|---:|---:|---:|---:|---:|---:|---:|
# | count | 11 | 11 | 11 | 11 | 11 | 11 | 11 | 11 |
# | mean | 9 | 7.5 | 9 | 7.5 | 9 | 7.5 | 9 | 7.5 |
# | std | 3.32 | 2.03 | 3.32 | 2.03 | 3.32 | 2.03 | 3.32 | 2.03 |
# | min | 4 | 4.26 | 4 | 3.1 | 4 | 5.39 | 8 | 5.25 |
# | 25% | 6.5 | 6.32 | 6.5 | 6.7 | 6.5 | 6.25 | 8 | 6.17 |
# | 50% | 9 | 7.58 | 9 | 8.14 | 9 | 7.11 | 8 | 7.04 |
# | 75% | 11.5 | 8.57 | 11.5 | 8.95 | 11.5 | 7.98 | 8 | 8.19 |
# | max | 14 | 10.8 | 14 | 9.26 | 14 | 12.7 | 19 | 12.5 |

# %%
print(type(dataset_1.describe()))
dataset_1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %% [markdown]
# ##### anscomes의 각 dataset 에 확장하자
# 1) 먼저 dataset_i 로 작업을 하면

# %%
import pandas as pd

# %% [markdown]
# 문자열을 파이썬 객체로 변경하기 위해서는 eval 함수를 이용한다.

# %%
anscomes = []
anscomes.append(dataset_1.describe())
anscomes.append(dataset_2.describe())
anscomes.append(dataset_3.describe())
anscomes.append(dataset_4.describe())
tmp = pd.concat(anscomes, axis=1)
tmp.columns=['x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'x4', 'y4']
tmp
# Out:
#               x1         y1         x2  ...         y3         x4         y4
# count  11.000000  11.000000  11.000000  ...  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000  ...   7.500000   9.000000   7.500909
# std     3.316625   2.031568   3.316625  ...   2.030424   3.316625   2.030579
# min     4.000000   4.260000   4.000000  ...   5.390000   8.000000   5.250000
# 25%     6.500000   6.315000   6.500000  ...   6.250000   8.000000   6.170000
# 50%     9.000000   7.580000   9.000000  ...   7.110000   8.000000   7.040000
# 75%    11.500000   8.570000  11.500000  ...   7.980000   8.000000   8.190000
# max    14.000000  10.840000  14.000000  ...  12.740000  19.000000  12.500000
#
# [8 rows x 8 columns]

# %%
anscomes = []
for i in range(1, 5):
    tmp = eval('dataset_'+str(i)).describe()
    tmp.columns = [col + str(i) for col in tmp.columns]
    anscomes.append(tmp)
pd.concat(anscomes, axis=1)
# Out:
#               x1         y1         x2  ...         y3         x4         y4
# count  11.000000  11.000000  11.000000  ...  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000  ...   7.500000   9.000000   7.500909
# std     3.316625   2.031568   3.316625  ...   2.030424   3.316625   2.030579
# min     4.000000   4.260000   4.000000  ...   5.390000   8.000000   5.250000
# 25%     6.500000   6.315000   6.500000  ...   6.250000   8.000000   6.170000
# 50%     9.000000   7.580000   9.000000  ...   7.110000   8.000000   7.040000
# 75%    11.500000   8.570000  11.500000  ...   7.980000   8.000000   8.190000
# max    14.000000  10.840000  14.000000  ...  12.740000  19.000000  12.500000
#
# [8 rows x 8 columns]

# %% [markdown]
# 2) 위 작업방식을 anscombe에서 직접 수행하면:

# %%
anscomes = []
for i, c in enumerate(['I', 'II', 'III', 'IV']):
    tmp = anscombe[anscombe.dataset == c].describe()
    tmp.columns = [col + str(i+1) for col in tmp.columns]
    anscomes.append(tmp)

# %%
import numpy as np
anscomes = []
for i, (_, sub) in enumerate(anscombe.groupby('dataset')):
    tmp = sub.describe()
    tmp.columns = [col + str(i+1) for col in tmp.columns]
    anscomes.append(tmp)
pd.concat(anscomes, axis=1)
# Out:
#               x1         y1         x2  ...         y3         x4         y4
# count  11.000000  11.000000  11.000000  ...  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000  ...   7.500000   9.000000   7.500909
# std     3.316625   2.031568   3.316625  ...   2.030424   3.316625   2.030579
# min     4.000000   4.260000   4.000000  ...   5.390000   8.000000   5.250000
# 25%     6.500000   6.315000   6.500000  ...   6.250000   8.000000   6.170000
# 50%     9.000000   7.580000   9.000000  ...   7.110000   8.000000   7.040000
# 75%    11.500000   8.570000  11.500000  ...   7.980000   8.000000   8.190000
# max    14.000000  10.840000  14.000000  ...  12.740000  19.000000  12.500000
#
# [8 rows x 8 columns]

# %% [markdown]
# concat시 keys를 부여하여 계층적 열이름을 사용해보자.

# %%
anscomes = []
keys = []
for i in range(1, 5):
    key = 'dataset_' + str(i)
    anscomes.append(eval(key).describe())
    keys.append(key)
    
mcoldf = pd.concat(anscomes, axis=1, keys=keys, names=['dataset', 'colname'])
mcoldf
# Out:
# dataset  dataset_1             dataset_2  ...  dataset_3  dataset_4
# colname          x          y          x  ...          y          x          y
# count    11.000000  11.000000  11.000000  ...  11.000000  11.000000  11.000000
# mean      9.000000   7.500909   9.000000  ...   7.500000   9.000000   7.500909
# std       3.316625   2.031568   3.316625  ...   2.030424   3.316625   2.030579
# min       4.000000   4.260000   4.000000  ...   5.390000   8.000000   5.250000
# 25%       6.500000   6.315000   6.500000  ...   6.250000   8.000000   6.170000
# 50%       9.000000   7.580000   9.000000  ...   7.110000   8.000000   7.040000
# 75%      11.500000   8.570000  11.500000  ...   7.980000   8.000000   8.190000
# max      14.000000  10.840000  14.000000  ...  12.740000  19.000000  12.500000
#
# [8 rows x 8 columns]

# %%
mcoldf.columns
# Out:
# MultiIndex([('dataset_1', 'x'),
#             ('dataset_1', 'y'),
#             ('dataset_2', 'x'),
#             ('dataset_2', 'y'),
#             ('dataset_3', 'x'),
#             ('dataset_3', 'y'),
#             ('dataset_4', 'x'),
#             ('dataset_4', 'y')],
#            names=['dataset', 'colname'])

# %%
mcoldf.stack(0).unstack(0)
# Out:
# colname      x                         ...     y
#            25%  50%   75% count   max  ... count    max      mean   min       std
# dataset                                ...
# dataset_1  6.5  9.0  11.5  11.0  14.0  ...  11.0  10.84  7.500909  4.26  2.031568
# dataset_2  6.5  9.0  11.5  11.0  14.0  ...  11.0   9.26  7.500909  3.10  2.031657
# dataset_3  6.5  9.0  11.5  11.0  14.0  ...  11.0  12.74  7.500000  5.39  2.030424
# dataset_4  8.0  8.0   8.0  11.0  19.0  ...  11.0  12.50  7.500909  5.25  2.030579
#
# [4 rows x 16 columns]

# %% [markdown]
# ### 2. 기초 그래프 그리기
# 히스토그램, 산점도, 박스 그래프(84쪽)

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(tips.shape)
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# (244, 7)
# <class 'pandas.core.frame.DataFrame'>

# %%
plt.close('all')

# %% [markdown]
# #### 히스토그램
# histogram vs. bar chart

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1) 
# axes1 = fig.add_subplot(111)

# %%
type(axes1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# 이 fig에 지불금액에 대한 histogram을 그려보자.

# %%
axes1.hist(tips['total_bill'], bins=10, alpha=.5)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Frequency') 

fig

# %% [markdown]
# #### [Quiz] 팁에 대한 히스토그램을 그려보자.

# %%
# plt.close('all')
# fig = plt.figure()
# axes1 = fig.add_subplot(111)

axes1.hist(tips['tip'], bins=10, alpha=.5)
axes1.set_title('Histogram of tip')
axes1.set_xlabel('tip') 
axes1.set_ylabel('Frequency') 

fig

# %%
fig = plt.figure()
axes1 = fig.add_subplot(111)

axes1.hist(tips['tip'], bins=10, alpha=.5)
axes1.set_title('Histogram of tip')
axes1.set_xlabel('tip') 
axes1.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# [Quiz] plot 메소드를 이용하여 total_bill에 대한 히스토그램을 그려보자.

# %%
tips.total_bill.plot(kind='hist')

# %%
tips.total_bill.plot.hist()

# %%
ax = tips.total_bill.hist()
ax.set_xlabel('total_bil')
ax.set_ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
tips.hist('total_bill')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f008b326990>]],
#       dtype=object)

# %% [markdown]
# 각 column 별로 별도의 axes를 만들어서 따로 그린다.

# %%
tips.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f008b2143d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0093e88410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0093e933d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f008b2080d0>]],
#       dtype=object)

# %% [markdown]
# 아래와 같이 하나의 도화지에 모두 그릴 때는 스케일이 제일 큰 total_bill로 부터 구간이 나눠지고 이 때문에, tip, size의 분포는 알수가 없게됩니다.
# - 한번에 그릴 때는 각 열의 스케일이 유사할 때, 한번에 그리고
# - 스케일이 다를 때는 각각 별도로 그려야 한다.
# - 만약 한버에 굳이 그리고자 하면, bins을 늘려야 한다.

# %%
tips.plot.hist(bins=30)

# %% [markdown]
# #### 산점도
# 이번에는 지불금액과 팁에 대한 산점도를 그려보자. 성별로 구분해볼까?

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot() 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
tips.plot.scatter('total_bill', 'tip')

# %% [markdown]
# 성별로 구분해볼까?

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot()
sexcol = np.where(tips.sex == 'Male', 'b', 'r')

axes1.scatter(tips['total_bill'], tips['tip'], c=sexcol) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
tips.plot.scatter('total_bill', 'tip', c=sexcol)

# %% [markdown]
# [Quiz] size와 total_bill에 대한 산점도를 작성하라.

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot() 
axes1.scatter(tips['size'], tips['total_bill']) 
axes1.set_title('Scatterplot of Total Bill vs Size') 
axes1.set_xlabel('size') 
axes1.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### boxplot
# 성별로 팁에 대한 boxplot을 그려보자. 이를 위해 성별 팁에 대한 Series 데이터를 생성하여 리스트로 전달한다.

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips.loc[tips['sex'] == 'Female', 'tip'], 
     tips.loc[tips['sex'] == 'Male', 'tip']], 
    labels=['Female', 'Male'])

axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# 박스플랏에서의 이상치 식별:
# - x > Q3 + 1.5 * IQR
# - x < Q1 - 1.5 * IQR

# %% [markdown]
# #### [Quiz] 성별로 지불금액 대비 팁의 비율을 boxplot으로 그리면:

# %%
tips['tipRate'] = tips.tip / tips.total_bill

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)

axes1.boxplot( 
    [tips.loc[tips['sex'] == 'Female', 'tipRate'], 
     tips.loc[tips['sex'] == 'Male', 'tipRate']], 
    labels=['Female', 'Male'])

axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip Rate') 
axes1.set_title('Boxplot of Tip Rate by Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Boxplot of Tip Rate by Sex')

# %%
tips.boxplot('tipRate', 'sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### 다변량 데이터로 다변량 그래프 그리기 ─ 산점도 그래프(89쪽)
# 3 변수 이상을 그래프로 시각화하는 것.
#
# 지불금액과 팁의 산점도에 성별을 색상으로 달리 표현해보자.

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].map(recode_sex)
tips[['sex', 'sex_color']].head()
# Out:
#       sex sex_color
# 0  Female         0
# 1    Male         1
# 2    Male         1
# 3    Male         1
# 4  Female         0

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1) 
axes1.scatter(
    x=tips['total_bill'], 
    y=tips['tip'],    
    s=tips['size'] * 10,    
    c=tips['sex_color'],
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ## seaborn으로 그리기
# ### 단변량 그래프 그리기 ― 히스토그램(91쪽)

# %%
import seaborn as sns

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# fig, ax = plt.subplots()
ax = sns.distplot(tips['total_bill']) 
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
fig, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], kde=False) 
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# kde는 kernel density estimate로서 데이터 공간에서의 밀도 분포를 예측하는 방법이다. 보통 gaussian kernel method를 사용한다.
#
# 자세한 내용은 https://scikit-learn.org/stable/modules/density.html 을 참고한다.

# %%
fig, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist=False) 
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %% [markdown]
# 러그(rug) 플롯은 데이터 위치를 x축 위에 작은 선분(rug)으로 나타내어 실제 데이터들의 위치를 보여준다.

# %%
fig, ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True) 
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# DataFrame의 범주형 변수에 대한 bar chart를 제공하는 countplot을 사용한다.

# %%
fig, ax = plt.subplots() 
ax = sns.countplot('day', data=tips) 
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# [Quiz] size 데이터에 대해, bar 챠트를 생성해보자.

# %%
fig, ax = plt.subplots() 
ax = sns.countplot('size', data=tips) 
ax.set_title('Count of size') 
ax.set_xlabel('Number of Person') 
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd
freqs = {}
for k, g in tips.groupby('size'):
    freqs[k] = len(g)
pd.Series(freqs).plot(kind='bar')

# %%
tips.groupby('size').size().plot(kind='bar')

# %%
tips.groupby('size').size()
# Out:
# size
# 1      4
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# dtype: int64

# %%
tips['size'].plot.hist()

# %% [markdown]
# ## 다양한 종류의 이변량 그래프 그리기(95쪽)

# %% [markdown]
# ### 1. seaborn 라이브러리로 산점도 그래프 그리기
# seaborn 라이브러리는 matplotlib 라이브러리보다 다양한 방법으로 산점도 그래프를 그릴 수 있다. 산점도 그래프를 그리려면 seaborn 라이브러리의 regplot 함수를 사용한다.

# %%
fig, ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
fig, ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# log를 이용한 산점도

# %%
import numpy as np
log10tb = tips.total_bill.map(np.log10)
log10tip = tips.tip.map(np.log10)

# %%
fig, ax = plt.subplots() 
ax = sns.regplot(x=log10tb, y=log10tip, fit_reg=True) 
ax.set_title('Scatterplot of log Total Bill and log Tip') 
ax.set_xlabel('log Total Bill') 
ax.set_ylabel('log Tip')
plt.axis('equal')
# Out:
# (0.42619783450553095,
#  1.766889735881951,
#  -0.2278847923983843,
#  1.058470704399923)

# %% [markdown]
# 이번에는 산점도 그래프와 히스토그램을 한 번에 그려주는 jointplot 메서드를 사용해 보자.

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips, alpha=.3) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# JointGrid를 이용하야 joinplot을 좀 더 정밀하게 조정할 수 있다.

# %%
import seaborn as sns
grid = sns.JointGrid(x='total_bill', y='tip', data=tips)

g = grid.plot_joint(sns.scatterplot, hue='time', data=tips)
sns.kdeplot(tips.loc[tips['time']=='Dinner', 'total_bill'], ax=g.ax_marg_x, legend=False)
sns.kdeplot(tips.loc[tips['time']=='Lunch', 'total_bill'], ax=g.ax_marg_x, legend=False)
sns.kdeplot(tips.loc[tips['time']=='Dinner', 'tip'], ax=g.ax_marg_y, vertical=True, legend=False)
sns.kdeplot(tips.loc[tips['time']=='Lunch', 'tip'], ax=g.ax_marg_y, vertical=True, legend=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어렵다는 단점이 있다. 산점도 그래프의 데이터 밀도를 구분하기 쉽게 그리고 싶다면 육각 그래프(hexbin)를 사용하면 된다.

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# ### 4. 이차원 밀집도 그리기
# 이차원 밀집도는 kdeplot 메서드로 만들 수 있다. 이때 shade 옵션 값을 True로 지정하면 그래프에 음영 효과를 줄 수 있다.

# %%
kde, ax = plt.subplots() 
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 5. 바 그래프 그리기
# 점심과 저녁 식사에 대한 평균 지불비용을 그려보자. estimator의 기본 값이 mean이므로 평균을 계산한다.

# %%
fig, ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
fig, ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips, estimator=np.median) 
ax.set_title('Bar plot of median total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('median total bill')
# Out:
# Text(0, 0.5, 'median total bill')

# %% [markdown]
# [Quiz] day 별로 평균 tiprate를 그려보자.

# %%
tips['tipRate'] = tips.tip / tips.total_bill

ax = sns.barplot(x='day', y='tipRate', data=tips) 
ax.set_title('Bar plot of average tip rate for day') 
ax.set_xlabel('day') 
ax.set_ylabel('Average tip rate')
# Out:
# Text(0, 0.5, 'Average tip rate')

# %%
ax = tips.groupby('day')['tipRate'].mean().plot(kind='bar', color=list('bgrk'))
ax.set_title('mean tipRate per day')
ax.set_xlabel('day')
ax.set_ylabel('mean tipRate')
# Out:
# Text(0, 0.5, 'mean tipRate')

# %% [markdown]
# [Quiz] day 별 평균 tipRate로 아래와 같이 bar chart를 그리는데, DataFrame의 plot 메소드를 이용하세요.

# %%
tips.groupby(['day', 'sex'])['tipRate'].mean().unstack()
# Out:
# sex       Male    Female
# day
# Thur  0.165276  0.157525
# Fri   0.143385  0.199388
# Sat   0.151577  0.156470
# Sun   0.162344  0.181569

# %% [markdown]
# plot(kind='bar')를 할 때:
# - index가 x로 가고, 각 열들이 y를 구성한다.
# - 이때, 이를 쌓아서 그리기 위해 stacked 옵션을 True로 줍니다.

# %%
dayPerSexTipRate = tips.groupby(['day', 'sex'])['tipRate'].mean().unstack()
dayPerSexTipRate.plot(kind='bar', stacked=True)

# %% [markdown]
# ### 6. 박스 그래프 그리기
# pyplot의 boxplot과 달리, sns의 boxplot 함수는 x에 범주형 변수를 y에 연속형 변수를 지정하면, 자동으로 범주별 boxplot을 그려준다.

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# boxplot은 range만을 표시할 뿐 데이터의 밀도를 이해하기는 어렵다. 이에 kde를 이용하여 데이터의 분포까지도 표시하는 violinplot을 이용하면 range와 분포까지도 시각화할 수 있다.

# %%
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# 위 violinplot을 boxplot과 비교해보면, kde를 사용하므로, 실제 데이터가 없는 영역도 밀도가 표시되는 문제가 있으므로, 이를 고려하여 해석해야 한다.

# %% [markdown]
# ### 8. 관계 그래프 그리기
# 모든 연속형 변수에 대해 산점도와 히스토그램을 한번에 보여준다.

# %%
fig = sns.pairplot(tips)

# %% [markdown]
# pairplot을 더 발전시켜, 각 연속형 변수쌍에 대한 Grid figure를 생성하고:
# - map_upper에 regplot을 그려 대각 상단 삼각셀에 산점도와 회귀선을
# - map_diag에 distplot을
# - map_lower에 kdeplot으로 두 변수간 분포밀도를 그릴 수 있다.

# %%
plt.close('all')
sns.PairGrid(tips).map_upper(sns.regplot).map_lower(sns.kdeplot).map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 다변량 그래프 그리기(103쪽)

# %% [markdown]
# ### 1. seaborn 라이브러리로 바이올린 그래프 그리기 ― 색상 추가
# 남녀별로 서로 다른 분포를 시각화하기 위해 비대칭 violinplot을 그린다. 이때, hue에 sex를 설정한다.

# %%
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, 
                    split=True) 
plt.show()

# %% [markdown]
# [Quiz] 당신이 웨이터라면, 남자손님과 여자손님이 올 때, 어떤 손님에게 서비스를 해야 더 많은 팁을 기대할 수 있는 지를 알아야 돈을 더 받을 수 있을 것이다. 이를 위해 size별로 tipRate를 그려보는데, 남녀별로 색을 달리하여 그려보자.

# %%
tips['tipRate'] = tips.tip / tips.total_bill
sns.violinplot(x='size', y='tipRate', hue='sex', data=tips, split=True)

# %%
tips.groupby(['size', 'sex']).tipRate.mean().unstack()
# Out:
# sex       Male    Female
# size
# 1     0.223776  0.215131
# 2     0.162694  0.170830
# 3     0.147641  0.159899
# 4     0.150197  0.132734
# 5     0.133821  0.172194
# 6     0.149567  0.162891

# %%
tips.groupby(['size', 'sex']).tipRate.agg(['size', 'mean']).unstack()
# Out:
#      size             mean
# sex  Male Female      Male    Female
# size
# 1       1      3  0.223776  0.215131
# 2      98     58  0.162694  0.170830
# 3      24     14  0.147641  0.159899
# 4      28      9  0.150197  0.132734
# 5       4      1  0.133821  0.172194
# 6       2      2  0.149567  0.162891

# %%
tips.groupby(['size', 'sex']).total_bill.agg(['size', 'mean']).unstack()
# Out:
#      size              mean
# sex  Male Female       Male     Female
# size
# 1       1      3   8.580000   6.796667
# 2      98     58  17.104082  15.339483
# 3      24     14  24.287083  21.547143
# 4      28      9  28.078214  30.278889
# 5       4      1  30.122500  29.850000
# 6       2      2  41.235000  28.425000

# %% [markdown]
# tipRate로 봤을 때는 여성이 후하지만, 남성이 절대적인 (비싼, 많은 양)음식요금이 높아, 팁도 더 많이 지불하고 있다. 따라서, 웨이터는 남성 손님을 서빙하는 것이 좋겠다.

# %%
tips.groupby(['size', 'sex']).tip.agg(['size', 'mean']).unstack()
# Out:
#      size             mean
# sex  Male Female      Male    Female
# size
# 1       1      3  1.920000  1.276667
# 2      98     58  2.614184  2.528448
# 3      24     14  3.476667  3.250000
# 4      28      9  4.172143  4.021111
# 5       4      1  3.750000  5.140000
# 6       2      2  5.850000  4.600000

# %% [markdown]
# ### 2. 산점도, 관계 그래프 그리기 ― 색상(hue) 추가
# HSV 컬러모델에 대한 이해:
# ![HSV](https://upload.wikimedia.org/wikipedia/commons/thumb/8/8f/HSV_cylinder.jpg/200px-HSV_cylinder.jpg)
# ![hue 값에 따른 생상](https://t1.daumcdn.net/cfile/tistory/2705763659488FB401)
#
# regplot과 유사하게 산점도와 회귀직선을 그릴 수 있지만, hue(색상) 옵션을 통헤 색상을 달리 설정할 수 있다.

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', 
                     fit_reg=False) 
plt.show()

# %% [markdown]
# hue에 지정되는 기본 색상이 마음이 들지 않으면 palette 옵션을 통해 변경할 수 있다.
#
# 다양한 빠레뜨에 대한 값은 [관련 문서](https://seaborn.pydata.org/tutorial/color_palettes.html)를 참고한다.
#
# 여기서는 flatui 빠레뜨를 사용해보자.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, 
                     hue='sex', fit_reg=False, palette=flatui) 
plt.show()

# %% [markdown]
# pairplot도 hue 옵션을 통해 색상을 선택할 수 있다.

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# ### 3. 산점도 그래프의 크기와 모양 조절하기
# pyplot의 scatter 함수의 옵션을 scatter_kws 옵션을 통해 dictionary 형태로 설정할 수 있다. 이때 legend가 자동으로 생성된다.

# %%
# scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, 
#                      hue='sex', scatter_kws={'s': tips['size']*10})
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, 
                     hue='sex')
# scatter = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)

plt.show()

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', 
                     markers=['o', 'x']) 
plt.show()

# %% [markdown]
# [Quiz] size와 sex 별로 크로스 테이블을 작성하고, 이를 시각화해보세요.

# %%
tipss = tips.copy()
tipss['cnt'] = 1

# %%
tipss.groupby(['size', 'sex'])['cnt'].sum().unstack()
# Out:
# sex   Male  Female
# size
# 1        1       3
# 2       98      58
# 3       24      14
# 4       28       9
# 5        4       1
# 6        2       2

# %%
tips[['size', 'sex']].groupby(['size', 'sex']).agg('size').unstack()
# Out:
# sex   Male  Female
# size
# 1        1       3
# 2       98      58
# 3       24      14
# 4       28       9
# 5        4       1
# 6        2       2

# %%
sexsize = tips[['size', 'sex']].groupby(['size', 'sex']).agg('size').unstack()
sexsize.plot(kind='bar')

# %%
tips.groupby(['size', 'sex']).size().unstack().plot(kind='bar')

# %% [markdown]
# ### 5. lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %% [markdown]
# 그룹별로 쉽게 나눠 그리는 방법은 컬럼을 의미는 col에 그룹을 지정하고, col_wrap에 열의 최대값을 설정하면 된다.

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, 
                           col='dataset', col_wrap=2, hue='dataset')

# %% [markdown]
# f<font color='red'> [Quiz] </font> tips 데이터를 이용하여, tip과 total_bill로 산점도를 그리되, sex와 smoker 별로 2x2 lmplot을 그려본다.

# %% [markdown]
# 색을 달리하기 위해, sex와 smpoker를 모두 구분지을 수 있는 새로운 categrical 변수를 생성하여 hue 에 지정할 수 있다.

# %%
tips['sexsmok'] = tips.sex.astype('str') + tips.smoker.astype('str')
tips['sexsmok'] = pd.Categorical(tips['sexsmok'])
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
#  7   tipRate     244 non-null    float64
#  8   sexsmok     244 non-null    category
# dtypes: category(5), float64(3), int64(1)
# memory usage: 9.6 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tipRate   sexsmok
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447  FemaleNo
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542    MaleNo
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587    MaleNo
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780    MaleNo
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808  FemaleNo

# %% [markdown]
# pd.Categorical 한것은 아래와 같은 연산을 수행한 것과 거의 동일한 메모리 사이즈를 갖는다.
# ```python
# tips['sexsmok'] = np.where(tips.sex == 'Female', 0, 2) + \
#                   np.where(tips.smoker == 'No', 0, 1)
# ```

# %%
tips_plot = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, 
                       row = 'sex', col='smoker', hue='sexsmok')

# %% [markdown]
# ### 알아두면 좋아요!
# #### FacetGrid 클래스로도 그룹별 그래프를 그릴 수 있습니다(108쪽)

# %%
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# FacetGrid는 plt.subplots 처럼 여러 ax를 생성하지만, 차이점이 있다면, 입력된 DataFrame의 정보를 유지하여, axes의 array라기 보다는 axes의 Series로 동작한다. 따라서 이에 대한 map 함수가 존재한다.

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %% [markdown]
# [Quiz] 위 이미지를 2, 2 이미지로 그려라.

# %%
plt.scatter

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex', col_wrap=2) 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend()

# %%
tips_plot = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, 
                       col='day', hue='sex', col_wrap=2)

# %%
tips_plot = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, 
                       col='day', hue='sex', col_wrap=2, size=4, 
                       scatter_kws={"s": 20})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 이번에는 다양한 범주에 대해 Facet을 적용해보자.

# %%
facet = sns.FacetGrid(tips, col='day', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ### 데이터프레임과 시리즈로 그래프 그리기(110쪽)
# pandas의 plot 메소드로 바로 그래프를 그릴 수 있다.
# - df.plot(kind=' '): bar, box, hist, pie, scatter, area - 기본적으로 하나의 axes를 사용
# - df.plot.bar(), df.plot.box(), ...

# %%
tips['total_bill'].plot.hist()

# %%
ax = tips['total_bill'].plot(kind='hist')

# %% [markdown]
# 두개의 변수에 대해 한번에 히스토그램을 그릴 수 있다.

# %%
# fig, ax = plt.subplots() 
# ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)
tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20)

# %%
tips[['total_bill', 'tip']].plot(kind='hist', alpha=0.5, bins=20, subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f00811eef90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f0081137dd0>],
#       dtype=object)

# %% [markdown]
# pandas의 plot 메소드를 이용하는 방법

# %%
tips['tip'].plot.kde()

# %%
fig, axes = plt.subplots(1, 2)
tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=axes[0])
tips['tip'].plot.kde(ax=axes[1])

# %%
# fig, ax = plt.subplots() 
# ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
ax = tips.plot.scatter(x='total_bill', y='tip')

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=30, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips.plot.box(ax=ax)

# %%
fig, axes = plt.subplots(1, 3, sharey=True) 
boxBill = tips['total_bill'].plot.box(ax=axes[0]) 
boxTip = tips['tip'].plot.box(ax=axes[1]) 
boxSize = tips['size'].plot.box(ax=axes[2])

# %% [markdown]
# <font color="red">[Quiz]</font> FacetGrid로 생성한 아래와 같은 그림을 pandas의 plot 메소드로 그려보자.
# ![](https://i.imgur.com/tPkPNHS.png)

# %% [markdown]
# 아래와 같은 방법으로 문제를 해결한다.
# 1. 현재 seaborn의 palette에 있는 색을 찾아내자.
# 2. 색과 sex를 매팅하는 사전을 정의한다.
# 3. plt.subplots를 이용하여 각 ax에 tips의 plot 메소드로 그려넣는다.
#
# 먼저 현재 seaborn의 palette에 있는 색을 찾아내자.

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# 성별로 서로 다른 색상을 적용하기 위해 단지 첫 2개의 색상만 필요하다.

# %%
current_palette[:2]
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725)]

# %% [markdown]
# 이 색들은 3차원의 RGB 색상값으로 0 ~ 1 값은 갖는다. 이를 pyplot에서 이해할 수 있는 RGB 포맷의 문자열("#ffffff")로 변경하자.

# %%
 hex(round(current_palette[0][0] * 255))
# Out:
# '0x1f'

# %%
cur_colors = {}
sexes = ['Male', 'Female']
for i in range(2):
    col = []
    for j in range(3):
        tmpstr = hex(round(current_palette[i][j] * 255))[2:]
        tmpstr = '0' + tmpstr if len(tmpstr) < 2 else tmpstr
        col.append(tmpstr)
    cur_colors[sexes[i]]= '#' + ''.join(col)
cur_colors
# Out:
# {'Female': '#ff7f0e', 'Male': '#1f77b4'}

# %% [markdown]
# 이제, 이 cur_colors를 이용하여 plt.subplots의 각 ax에 산점도를 그려넣자.

# %%
fig, axes = plt.subplots(2,2, sharex=True, sharey=True, figsize=(10, 10))
plt.subplots_adjust(wspace=0.1, hspace=0.1)
smokeness = ['Yes', 'No']
timeness = ['Lunch', 'Dinner']
for i in range(axes.shape[0]):
    for j in range(axes.shape[1]):
        tmp = tips[(tips.smoker == smokeness[i])&(tips.time == timeness[j])]
        title = 'smoker = %s | time = %s' %(smokeness[i], timeness[j])
        sexclr = tmp.sex.map(lambda sex: cur_colors[sex])
        ax = axes[i][j]
        ax.set_title(title)
        tmp.plot.scatter('total_bill', 'tip', c=sexclr, ax=ax, s=30)

# %% [markdown]
# ### 그래프에 스타일 적용하기(114쪽)
# seaborn 라이브러리로 만든 그래프는 모두 기본 스타일이었다.
#
# seaborn 라이브러리로 만든 그래프의 스타일은 set_style 메서드를 사용하여 바꿀 수 있으며, 이를 실행한 이후의 모든 그래프는 지정한 스타일로 바뀐다.

# %%
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# whitegrid로 스타일을 변경하며, y축에 대한 그리드 선이 나타난다. 이 스타일은 이후로 계속 유지된다.

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# 이 설정은 계속 유지되며, boxplot에서 나타나지 않은 x축에 대한 grid bar를 추가로 보여준다.

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 다음은 for 문을 돌며 다양한 스타일로 그래프를 그리는 방법을 안내한다.

# %%
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', 
                                data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()

# %% [markdown]
# - ticks는 white에 비해 xticks와 yticks를 명확히 보여준다.
#
# seaborn으로 그리는 다양한 예제: https://seaborn.pydata.org/examples/index.html
#
# matplotlib의 다양한 예제: https://matplotlib.org/3.1.1/gallery/index.html
#
# 기타 갤러리: https://python-graph-gallery.com/
#
# pandas plot, pyplot, seaborn의 차이 이해: http://blog.naver.com/PostView.nhn?blogId=owl6615&logNo=221572486986&parentCategoryNo=118&categoryNo=113&viewDate=&isShowPopularPosts=false&from=postView
